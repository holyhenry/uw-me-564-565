# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
u = lambda x : 1/12*(-x**4 + 1000*x)

pos = np.linspace(0,10,100)
u_dist = []
for i in range(len(pos)):
    u_dist.append(u(pos[i]))
    
plt.plot(pos, u_dist)
plt.grid()
